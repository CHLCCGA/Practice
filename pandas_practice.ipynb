# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("D:\one drive\OneDrive - Uniwersytet Łódzki\桌面\数据科学\Pokemon.csv")

# %%
data
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
data.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
data.Speed.plot(kind = 'line', color = 'blue',label = 'Speed',linewidth=1,alpha = 0.5,grid = True,linestyle = ':')
data.Defense.plot(color = 'red',label = 'Defense',linewidth=1, alpha = 0.5,grid = True,linestyle = '-')
plt.legend(loc='upper right')     # 在图像中显示标签
plt.xlabel('x axis')              # 定义X轴名称
plt.ylabel('y axis')              # 定义y轴名称
plt.title('Line Plot')            # 定义图像名称
plt.show()                        # 显示图像

# %%
data.plot(kind='scatter', x='Attack', y='Defense',alpha = 0.5,color = 'red')
plt.xlabel('Attack')              
plt.ylabel('Defence')
plt.title('Attack Defense Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Attack Defense Scatter Plot')

# %%
data.HP.plot(kind='hist',bins=30,figsize=(5,3))
plt.legend()
plt.title('HP')
plt.show()

# %%
data.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
data.tail(10)
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 790  714               Noibat   Flying  Dragon    245   40      30       35
# 791  715              Noivern   Flying  Dragon    535   85      70       80
# 792  716              Xerneas    Fairy     NaN    680  126     131       95
# 793  717              Yveltal     Dark  Flying    680  126     131       95
# 794  718     Zygarde50% Forme   Dragon  Ground    600  108     100      121
# 795  719              Diancie     Rock   Fairy    600   50     100      150
# 796  719  DiancieMega Diancie     Rock   Fairy    700   50     160      110
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 799  721            Volcanion     Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 790       45       40     55           6      False
# ...

# %%
data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
data.shape
# Out:
# (800, 13)

# %%
data.info
# Out:
# <bound method DataFrame.info of        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
data.value_counts()
# Out:
# #    Name                   Type 1    Type 2    Total  HP   Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 1    Bulbasaur              Grass     Poison    318    45   49      49       65       65       45     1           False        1
# 479  RotomFrost Rotom       Electric  Ice       520    50   65      107      105      107      86     4           False        1
# 494  Victini                Psychic   Fire      600    100  100     100      100      100      100    5           True         1
# 492  ShayminSky Forme       Grass     Flying    600    100  103     75       120      75       127    4           True         1
# 487  GiratinaOrigin Forme   Ghost     Dragon    680    150  120     100      120      100      90     4           True         1
#                                                                                                                               ..
# ...

# %%
data['Legendary'].value_counts()
# Out:
# False    735
# True      65
# Name: Legendary, dtype: int64

# %%
data.boxplot(column=['Attack','Defense'])
plt.show()

# %%
data.boxplot(column='Attack',by='Legendary')
plt.show()

# %%
data.boxplot(column='Attack',by='Type 1')
plt.show()

# %%
data_new = data[:5]
data_new
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# ## melt

# %%
melted = pd.melt(frame=data_new,id_vars='Name',value_vars=['HP','Attack','Defense'])
melted
# Out:
#                      Name variable  value
# 0               Bulbasaur       HP     45
# 1                 Ivysaur       HP     60
# 2                Venusaur       HP     80
# 3   VenusaurMega Venusaur       HP     80
# 4              Charmander       HP     39
# 5               Bulbasaur   Attack     49
# 6                 Ivysaur   Attack     62
# 7                Venusaur   Attack     82
# 8   VenusaurMega Venusaur   Attack    100
# 9              Charmander   Attack     52
# 10              Bulbasaur  Defense     49
# 11                Ivysaur  Defense     63
# 12               Venusaur  Defense     83
# 13  VenusaurMega Venusaur  Defense    123
# 14             Charmander  Defense     43

# %% [markdown]
# ## pivot

# %%
melted.pivot(index='Name',columns='variable',values='value')
# Out:
# variable               Attack  Defense  HP
# Name
# Bulbasaur                  49       49  45
# Charmander                 52       43  39
# Ivysaur                    62       63  60
# Venusaur                   82       83  80
# VenusaurMega Venusaur     100      123  80

# %%
data1 = data.tail(6)
data2 = data.head(4)
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 794  718     Zygarde50% Forme   Dragon  Ground    600  108     100      121
# 795  719              Diancie     Rock   Fairy    600   50     100      150
# 796  719  DiancieMega Diancie     Rock   Fairy    700   50     160      110
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 799  721            Volcanion     Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 794       81       95     95           6       True
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
data3 = pd.concat([data1,data2],axis=0,ignore_index=False)
data3
# Out:
#        #                   Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 794  718       Zygarde50% Forme   Dragon  Ground    600  108     100      121
# 795  719                Diancie     Rock   Fairy    600   50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700   50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 799  721              Volcanion     Fire   Water    600   80     110      120
# 0      1              Bulbasaur    Grass  Poison    318   45      49       49
# 1      2                Ivysaur    Grass  Poison    405   60      62       63
# 2      3               Venusaur    Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625   80     100      123
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 794       81       95     95           6       True
# ...

# %%
data.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
data['Type 2'].value_counts(dropna=False)
# Out:
# NaN         386
# Flying       97
# Ground       35
# Poison       34
# Psychic      33
# Fighting     26
# Grass        25
# Fairy        23
# Steel        22
# Dark         20
# Dragon       18
# Ice          14
# Rock         14
# Water        14
# Ghost        14
# Fire         12
# Electric      6
# Normal        4
# Bug           3
# Name: Type 2, dtype: int64

# %%
data_copy = data
data_copy['Type 2'].dropna(inplace=True)
data_copy.dropna().head(10)
# Out:
#      #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0    1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1    2                    Ivysaur  Grass  Poison    405  60      62       63
# 2    3                   Venusaur  Grass  Poison    525  80      82       83
# 3    3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 6    6                  Charizard   Fire  Flying    534  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 15  12                 Butterfree    Bug  Flying    395  60      45       50
# 16  13                     Weedle    Bug  Poison    195  40      35       30
# 17  14                     Kakuna    Bug  Poison    205  45      25       50
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0        65       65     45           1      False
# ...

# %%
data['Type 2'].fillna('empty',inplace=True)
data.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire   empty    309  39      52       43
# 5  5                 Charmeleon   Fire   empty    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water   empty    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
assert data['Type 2'].notnull.all()

# %%
assert data.columns[1] == 'HP'
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11100\926632455.py in <module>
# ----> 1 assert data.columns[1] == 'HP'
#
# AssertionError:

# %%
plt.figure(figsize=(5,3))
data8 = data.loc[:,["Attack","Defense","Speed"]]
data8.plot()
plt.show()

# %%
plt.figure(figsize=(5,3))
data8 = data.loc[:,["Attack","Defense","Speed"]]
data8.plot(subplots=True)
plt.show()

# %%
data.plot(kind='scatter',x="Attack",y = "Defense")
plt.show()

# %%
data.plot(kind='hist',y='Attack',bins=40,range=(0,250),density=False)
plt.show()

# %%
# frequency
data.plot(kind='hist',y='Attack',bins=40,range=(0,250),density=True)
plt.show()

# %%
fig,axes = plt.subplots(nrows=2,ncols=1)
data.plot(kind='hist',y='Attack',bins=50,range=(0,250),density=True,ax=axes[0])
data.plot(kind='hist',y='Attack',bins=50,range=(0,250),density=True,ax=axes[1],cumulative=True)
plt.savefig('gragh_lianxi.png')
plt.show()

# %%
time_list = ["1992-03-08","1992-04-12"]
print(type(time_list[1])) # str
# datatime
datetime_object = pd.to_datetime(time_list)
print(type(datetime_object))
# Out:
# <class 'str'>
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
data2 = data.head()
date_list =  ["1992-01-10","1992-02-10","1992-03-10","1993-03-15","1993-03-16"]
# datetime
datetime_object = pd.to_datetime(date_list)
data2['date'] = datetime_object
# index
data2 = data2.set_index('date')
data2
# Out:
# C:\Users\25420\AppData\Local\Temp\ipykernel_3956\1121587665.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['date'] = datetime_object
#             #                   Name Type 1  Type 2  Total  HP  Attack  \
# date
# 1992-01-10  1              Bulbasaur  Grass  Poison    318  45      49
# 1992-02-10  2                Ivysaur  Grass  Poison    405  60      62
# 1992-03-10  3               Venusaur  Grass  Poison    525  80      82
# 1993-03-15  3  VenusaurMega Venusaur  Grass  Poison    625  80     100
# 1993-03-16  4             Charmander   Fire     NaN    309  39      52
#
#             Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# date
# 1992-01-10       49       65       65     45           1      False
# ...

# %%
data2.iloc[:,1]
# Out:
# date
# 1992-01-10                Bulbasaur
# 1992-02-10                  Ivysaur
# 1992-03-10                 Venusaur
# 1993-03-15    VenusaurMega Venusaur
# 1993-03-16               Charmander
# Name: Name, dtype: object

# %%
data2.loc['1992-01-10']
# Out:
# #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# Total               318
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 1992-01-10 00:00:00, dtype: object

# %%
data2.head()
# Out:
#             #                   Name Type 1  Type 2  Total  HP  Attack  \
# date
# 1992-01-10  1              Bulbasaur  Grass  Poison    318  45      49
# 1992-02-10  2                Ivysaur  Grass  Poison    405  60      62
# 1992-03-10  3               Venusaur  Grass  Poison    525  80      82
# 1993-03-15  3  VenusaurMega Venusaur  Grass  Poison    625  80     100
# 1993-03-16  4             Charmander   Fire     NaN    309  39      52
#
#             Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# date
# 1992-01-10       49       65       65     45           1      False
# 1992-02-10       63       80       80     60           1      False
# 1992-03-10       83      100      100     80           1      False
# 1993-03-15      123      122      120     80           1      False
# 1993-03-16       43       60       50     65           1      False

# %%
data2.resample('Y').mean()
# Out:
#               #  Total         HP     Attack  Defense    Sp. Atk    Sp. Def  \
# date
# 1992-12-31  2.0  416.0  61.666667  64.333333     65.0  81.666667  81.666667
# 1993-12-31  3.5  467.0  59.500000  76.000000     83.0  91.000000  85.000000
#
#                 Speed  Generation  Legendary
# date
# 1992-12-31  61.666667         1.0        0.0
# 1993-12-31  72.500000         1.0        0.0

# %%
data2.resample('M').mean()
# Out:
#               #  Total    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# date
# 1992-01-31  1.0  318.0  45.0    49.0     49.0     65.0     65.0   45.0
# 1992-02-29  2.0  405.0  60.0    62.0     63.0     80.0     80.0   60.0
# 1992-03-31  3.0  525.0  80.0    82.0     83.0    100.0    100.0   80.0
# 1992-04-30  NaN    NaN   NaN     NaN      NaN      NaN      NaN    NaN
# 1992-05-31  NaN    NaN   NaN     NaN      NaN      NaN      NaN    NaN
# 1992-06-30  NaN    NaN   NaN     NaN      NaN      NaN      NaN    NaN
# 1992-07-31  NaN    NaN   NaN     NaN      NaN      NaN      NaN    NaN
# 1992-08-31  NaN    NaN   NaN     NaN      NaN      NaN      NaN    NaN
# 1992-09-30  NaN    NaN   NaN     NaN      NaN      NaN      NaN    NaN
# 1992-10-31  NaN    NaN   NaN     NaN      NaN      NaN      NaN    NaN
# 1992-11-30  NaN    NaN   NaN     NaN      NaN      NaN      NaN    NaN
# 1992-12-31  NaN    NaN   NaN     NaN      NaN      NaN      NaN    NaN
# ...

# %%
# interpolate 插入
data2.resample('M').first().interpolate('linear')
# Out:
#               #                   Name Type 1  Type 2       Total    HP  \
# date
# 1992-01-31  1.0              Bulbasaur  Grass  Poison  318.000000  45.0
# 1992-02-29  2.0                Ivysaur  Grass  Poison  405.000000  60.0
# 1992-03-31  3.0               Venusaur  Grass  Poison  525.000000  80.0
# 1992-04-30  3.0                   None   None    None  533.333333  80.0
# 1992-05-31  3.0                   None   None    None  541.666667  80.0
# 1992-06-30  3.0                   None   None    None  550.000000  80.0
# 1992-07-31  3.0                   None   None    None  558.333333  80.0
# 1992-08-31  3.0                   None   None    None  566.666667  80.0
# 1992-09-30  3.0                   None   None    None  575.000000  80.0
# 1992-10-31  3.0                   None   None    None  583.333333  80.0
# 1992-11-30  3.0                   None   None    None  591.666667  80.0
# 1992-12-31  3.0                   None   None    None  600.000000  80.0
# ...

# %%
data2.resample('M').mean().interpolate('linear')
# Out:
#                    #       Total         HP  Attack  Defense  Sp. Atk  \
# date
# 1992-01-31  1.000000  318.000000  45.000000    49.0     49.0    65.00
# 1992-02-29  2.000000  405.000000  60.000000    62.0     63.0    80.00
# 1992-03-31  3.000000  525.000000  80.000000    82.0     83.0   100.00
# 1992-04-30  3.041667  520.166667  78.291667    81.5     83.0    99.25
# 1992-05-31  3.083333  515.333333  76.583333    81.0     83.0    98.50
# 1992-06-30  3.125000  510.500000  74.875000    80.5     83.0    97.75
# 1992-07-31  3.166667  505.666667  73.166667    80.0     83.0    97.00
# 1992-08-31  3.208333  500.833333  71.458333    79.5     83.0    96.25
# 1992-09-30  3.250000  496.000000  69.750000    79.0     83.0    95.50
# 1992-10-31  3.291667  491.166667  68.041667    78.5     83.0    94.75
# 1992-11-30  3.333333  486.333333  66.333333    78.0     83.0    94.00
# 1992-12-31  3.375000  481.500000  64.625000    77.5     83.0    93.25
# ...

# %%
data.HP.apply(lambda n:n**7)
# Out:
# 0        373669453125
# 1       2799360000000
# 2      20971520000000
# 3      20971520000000
# 4        137231006679
#             ...
# 795      781250000000
# 796      781250000000
# 797    20971520000000
# 798    20971520000000
# 799    20971520000000
# Name: HP, Length: 800, dtype: int64

# %%
data3 = data.copy()
data3.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
data3.index = range(100,1700,2)
data3
# Out:
#         #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 100     1              Bulbasaur    Grass  Poison    318  45      49       49
# 102     2                Ivysaur    Grass  Poison    405  60      62       63
# 104     3               Venusaur    Grass  Poison    525  80      82       83
# 106     3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 108     4             Charmander     Fire     NaN    309  39      52       43
# ...   ...                    ...      ...     ...    ...  ..     ...      ...
# 1690  719                Diancie     Rock   Fairy    600  50     100      150
# 1692  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 1694  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 1696  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 1698  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
data4 = data.set_index(['Type 1','Type 2'])
data4
# Out:
#                   #                   Name  Total  HP  Attack  Defense  \
# Type 1  Type 2
# Grass   Poison    1              Bulbasaur    318  45      49       49
#         Poison    2                Ivysaur    405  60      62       63
#         Poison    3               Venusaur    525  80      82       83
#         Poison    3  VenusaurMega Venusaur    625  80     100      123
# Fire    NaN       4             Charmander    309  39      52       43
# ...             ...                    ...    ...  ..     ...      ...
# Rock    Fairy   719                Diancie    600  50     100      150
#         Fairy   719    DiancieMega Diancie    700  50     160      110
# Psychic Ghost   720    HoopaHoopa Confined    600  80     110       60
#         Dark    720     HoopaHoopa Unbound    680  80     160       60
# Fire    Water   721              Volcanion    600  80     110      120
#
#                 Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Type 1  Type 2
# ...
